# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Описание-тарифов" data-toc-modified-id="Описание-тарифов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание тарифов</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Изучение-информации" data-toc-modified-id="Изучение-информации-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение информации</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-типов-данных-в-столбцах-столбцов" data-toc-modified-id="Изменение-типов-данных-в-столбцах-столбцов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Изменение типов данных в столбцах столбцов</a></span></li><li><span><a href="#Поиск-ошибок-и-обработка-данных" data-toc-modified-id="Поиск-ошибок-и-обработка-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Поиск ошибок и обработка данных</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Расчёт-выручки" data-toc-modified-id="Расчёт-выручки-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Расчёт выручки</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Проверка-статистических-гипотез" data-toc-modified-id="Проверка-статистических-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка статистических гипотез</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-№1" data-toc-modified-id="Проверка-гипотезы-№1-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проверка гипотезы №1</a></span></li><li><span><a href="#Проверка-гипотезы-№2" data-toc-modified-id="Проверка-гипотезы-№2-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверка гипотезы №2</a></span><ul class="toc-item"><li><span><a href="#Статистические-расчёты-по-гипотезе-№2" data-toc-modified-id="Статистические-расчёты-по-гипотезе-№2-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Статистические расчёты по гипотезе №2</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта
#
# Я аналитик компании «Мегалайн» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.
# Вам предстоит сделать предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.
# ### Описание тарифов
# Тариф «Смарт»
#
# 1. Ежемесячная плата: 550 рублей
#
# 2. Включено 500 минут разговора, 50 сообщений и 15 Гб интернет-трафика
#
# 3. Стоимость услуг сверх тарифного пакета:
# - минута разговора: 3 рубля
# - сообщение: 3 рубля
# - 1 Гб интернет-трафика: 200 рублей
#
# Тариф «Ультра»
# 1. Ежемесячная плата: 1950 рублей
# 2. Включено 3000 минут разговора, 1000 сообщений и 30 Гб интернет-трафика
# 3. Стоимость услуг сверх тарифного пакета:
# - минута разговора: 1 рубль
# - сообщение: 1 рубль
# - 1 Гб интернет-трафика: 150 рублей
# Примечание:
#
# «Мегалайн» всегда округляет секунды до минут, а мегабайты — до гигабайт. Каждый звонок округляется отдельно: даже если он длился всего 1 секунду, будет засчитан как 1 минута.
#
# Для веб-трафика отдельные сессии не считаются. Вместо этого общая сумма за месяц округляется в бо́льшую сторону. Если абонент использует 1025 мегабайт в этом месяце, с него возьмут плату за 2 гигабайта.

# %% [markdown]
# ### Описание данных
#
# Таблица users (информация о пользователях):
# - `user_id` — уникальный идентификатор пользователя
# - `first_name` — имя пользователя
# - `last_name` — фамилия пользователя
# - `age` — возраст пользователя (годы)
# - `reg_date` — дата подключения тарифа (день, месяц, год)
# - `churn_date` — дата прекращения пользования тарифом (если значение пропущено, то тариф ещё действовал на момент выгрузки данных)
# - `city` — город проживания пользователя
# - `tariff` — название тарифного плана
# Таблица calls (информация о звонках):
# - `id` — уникальный номер звонка
# - `call_date` — дата звонка
# - `duration` — длительность звонка в минутах
# - `user_id` — идентификатор пользователя, сделавшего звонок
# Таблица messages (информация о сообщениях):
# - `id` — уникальный номер сообщения
# - `message_date` — дата сообщения
# - `user_id` — идентификатор пользователя, отправившего сообщение
# Таблица internet (информация об интернет-сессиях):
# - `id` — уникальный номер сессии
# - `mb_used` — объём потраченного за сессию интернет-трафика (в мегабайтах)
# - `session_date` — дата интернет-сессии
# - `user_id` — идентификатор пользователя
# Таблица tariffs (информация о тарифах):
# - `tariff_name` — название тарифа
# - `rub_monthly_fee` — ежемесячная абонентская плата в рублях
# - `minutes_included` — количество минут разговора в месяц, включённых в абонентскую плату
# - `messages_included` — количество сообщений в месяц, включённых в абонентскую плату
# - `mb_per_month_included` — объём интернет-трафика, включённого в абонентскую плату (в мегабайтах)
# - `rub_per_minute` — стоимость минуты разговора сверх тарифного пакета (например, если в тарифе 100 минут разговора в месяц, то со 101 минуты будет взиматься плата)
# - `rub_per_message` — стоимость отправки сообщения сверх тарифного пакета
# - `rub_per_gb` — стоимость дополнительного гигабайта интернет-трафика сверх тарифного пакета (1 гигабайт = 1024 мегабайта)

# %% [markdown]
# ## Изучение информации

# %% [markdown]
# Для начала:
# 1. Загрузим нужные библиотеки
# 2. Установим настройки библиотеки `pandas`
# 3. Загрузим информацию из файлов

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
pd.set_option('display.max_columns', 50)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
pth_fold = '/datasets/'

pth_calls = 'calls.csv'
pth_internet = 'internet.csv'
pth_messages = 'messages.csv'
pth_tariffs = 'tariffs.csv'
pth_users = 'users.csv'

pth1 = 'real_estate_data.csv'
pth2 = '/datasets/real_estate_data.csv'

try:
    data_calls = pd.read_csv(pth_calls)
    data_inet = pd.read_csv(pth_internet, index_col=0)
    data_mess = pd.read_csv(pth_messages)
    data_tarif = pd.read_csv(pth_tariffs)
    data_users = pd.read_csv(pth_users)
except:
    data_calls = pd.read_csv(pth_fold + pth_calls)
    data_inet = pd.read_csv(pth_fold + pth_internet, index_col=0)
    data_mess = pd.read_csv(pth_fold + pth_messages)
    data_tarif = pd.read_csv(pth_fold + pth_tariffs)
    data_users = pd.read_csv(pth_fold + pth_users)

# %% [markdown]
# Просмотрим информацию о таблицах и сами таблицы

# %%
dataset = (data_calls, data_inet, data_mess, data_tarif, data_users)

for data in dataset:
    data.info()
    display(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB
#               id   call_date  duration  user_id
# 0         1000_0  2018-07-25      0.00     1000
# 1         1000_1  2018-08-17      0.00     1000
# 2         1000_2  2018-06-11      2.85     1000
# 3         1000_3  2018-09-21     13.80     1000
# 4         1000_4  2018-12-15      5.18     1000
# ...          ...         ...       ...      ...
# 202602  1499_215  2018-12-26      0.76     1499
# 202603  1499_216  2018-10-18     18.83     1499
# 202604  1499_217  2018-11-10     10.81     1499
# 202605  1499_218  2018-10-06      4.27     1499
# 202606  1499_219  2018-12-14     19.62     1499
#
# [202607 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149396 entries, 0 to 149395
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            149396 non-null  object
#  1   mb_used       149396 non-null  float64
#  2   session_date  149396 non-null  object
#  3   user_id       149396 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.7+ MB
#               id  mb_used session_date  user_id
# 0         1000_0   112.95   2018-11-25     1000
# 1         1000_1  1052.81   2018-09-07     1000
# 2         1000_2  1197.26   2018-06-25     1000
# 3         1000_3   550.27   2018-08-22     1000
# 4         1000_4   302.56   2018-09-24     1000
# ...          ...      ...          ...      ...
# 149391  1499_152   318.90   2018-10-03     1499
# 149392  1499_153   490.13   2018-12-14     1499
# 149393  1499_154     0.00   2018-10-27     1499
# 149394  1499_155  1246.32   2018-11-26     1499
# 149395  1499_156   544.37   2018-10-26     1499
#
# [149396 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB
#               id message_date  user_id
# 0         1000_0   2018-06-27     1000
# 1         1000_1   2018-10-08     1000
# 2         1000_2   2018-08-04     1000
# 3         1000_3   2018-06-16     1000
# 4         1000_4   2018-12-05     1000
# ...          ...          ...      ...
# 123031  1499_179   2018-12-12     1499
# 123032  1499_180   2018-09-28     1499
# 123033  1499_181   2018-09-27     1499
# 123034  1499_182   2018-11-15     1499
# 123035  1499_183   2018-11-16     1499
#
# [123036 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
#      user_id  age  churn_date         city first_name  last_name    reg_date  \
# 0       1000   52         NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1       1001   41         NaN       Москва       Иван       Ежов  2018-11-01
# 2       1002   59         NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3       1003   23         NaN       Москва      Белла   Белякова  2018-08-17
# 4       1004   68         NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
# ..       ...  ...         ...          ...        ...        ...         ...
# 495     1495   65         NaN      Иркутск  Авксентий      Фокин  2018-08-28
# 496     1496   36         NaN      Вологда     Трифон     Блохин  2018-01-27
# 497     1497   32         NaN    Челябинск   Каролина     Агеева  2018-10-09
# 498     1498   68  2018-10-25  Владикавказ   Всеволод    Акимчин  2018-07-19
# 499     1499   35         NaN        Пермь     Гектор   Корнилов  2018-09-27
#
#     tariff
# 0    ultra
# 1    smart
# 2    smart
# 3    ultra
# 4    ultra
# ..     ...
# 495  ultra
# 496  smart
# 497  smart
# 498  smart
# 499  smart
#
# [500 rows x 8 columns]

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Изменение типов данных в столбцах столбцов

# %% [markdown]
# Изменим тип данных в столбцах с датами на `datetime` во всех таблицах и поосмотрим крайние значения дат.

# %%
# to datetime
extr = dict.fromkeys(['min', 'max'])
for data in dataset:
    for column in data.columns:
        if 'date' in column:            
            data[column] = pd.to_datetime(data[column], format='%Y-%m-%d', errors='coerce')
            # data[column] = data[column].values.astype('datetime64[D]')  # NOT FORGET
            try:
                if data[column].min() < extr['min']:
                    extr['min'] = data[column].min()        
            except:
                extr['min'] = data[column].min()
            try:
                if data[column].max() > extr['max']:
                    extr['max'] = data[column].max()        
            except:
                extr['max'] = data[column].max()

display(extr)
# Out:
# {'min': Timestamp('2018-01-01 00:00:00'),
#  'max': Timestamp('2018-12-31 00:00:00')}

# %% [markdown]
# Данные охватывают ровно один год (2018) для 500 пользователей - соответствует заявленным данным.

# %% [markdown]
# ### Поиск ошибок и обработка данных

# %% [markdown]
# Проверка на дубликаты:

# %%
# Checking duplicates
for data in dataset:
    if len(data[data.duplicated(keep=False)]) != 0:
        display(data[data.duplicated(keep=False)])

# %% [markdown]
# Строк-дубликатов не выявлено.
# Проверим столбцы `id`, `user_id` таблиц `data_calls`, `data_inet`, `data_mess` на соответствие друг другу:

# %%
# Checking columns 'id' and 'user_id'
quontity_data = {'calls': data_calls, 'internet': data_inet, 'messages': data_mess}
for  key, value in quontity_data.items():
    if len(value['user_id'].unique()) != len(value['id'].apply(lambda x: x[:4]).unique()):
        display(f'{key}-data has not enough users')

# %% [markdown]
# Здесь разночтений не выявлено.
#
# Добавим в таблицы `data_calls`, `data_inet`, `data_mess` столбцы  в которых указан месяц использования услугой связи:

# %%
for key, value in quontity_data.items():
    temp = value.select_dtypes(include='datetime').iloc[:, 0]
    name_col = 'month' + '_' + key
    value[name_col] = pd.DatetimeIndex(temp).month

# %% [markdown]
# Подготовим `data_tarif`, `data_users` для дальнейших расчётов:

# %%
data_tarif.set_index(data_tarif['tariff_name'], inplace=True)
data_tarif.drop('tariff_name', axis=1, inplace=True)

# %%
data_users.set_index(data_users['user_id'], inplace=True)
data_users.drop('user_id', axis=1, inplace=True)

# %%
data_tarif['mb_per_month_included'] = data_tarif['mb_per_month_included'] / 1024
data_tarif = data_tarif.rename({'mb_per_month_included': 'gb_per_month_included'}, axis=1)

# %% [markdown]
#    По условиям "Мегалайна" длительность разговоров в минутах округляется в большую сторону. Сделаем то же самое с табличными данными. Также переведём МБ в ГБ для удобства в расчётах и переименуем соответствующий столбец.

# %%
data_calls['duration'] = np.ceil(data_calls['duration'])
data_inet['mb_used'] = data_inet['mb_used'] / 1024
data_inet = data_inet.rename({'mb_used': 'gb_used'}, axis=1)

# %% [markdown]
# ### Подготовка данных
# Посчитаем для каждого пользователя:
# 1. количество сделанных звонков и израсходованных минут разговора по месяцам;
# 2. количество отправленных сообщений по месяцам;
# 3. объем израсходованного интернет-трафика по месяцам;
# 4. помесячную выручку с каждого пользователя (вычтим бесплатный лимит из суммарного количества звонков, сообщений и интернет-трафика; остаток умножим на значение из тарифного плана; прибавим абонентскую плату, соответствующую тарифному плану).
#
# Рассчитаем объёмы потреблённых услуг по пунктам и сведём в одну таблицу.

# %%
calls_sum = data_calls.pivot_table(index=['user_id', 'month_calls'], values='duration', aggfunc='sum')
calls_count = data_calls.groupby(['user_id', 'month_calls'])['user_id'].count()
mess_count = data_mess.groupby(['user_id', 'month_messages'])['id'].count()
inet_sum = data_inet.groupby(['user_id', 'month_internet'])['gb_used'].sum()

for df in calls_sum, calls_count, mess_count, inet_sum:
    df.index.rename('month', level=1, inplace=True)
    
result = calls_sum
for df in calls_count, mess_count, inet_sum:
    result = pd.merge(result, df, how='outer', left_index=True, right_index=True)

result
# Out:
#                duration  user_id    id    gb_used
# user_id month
# 1000    5         159.0     22.0  22.0   2.200674
#         6         172.0     43.0  60.0  22.689229
#         7         340.0     47.0  75.0  13.675430
#         8         408.0     52.0  81.0  13.726494
#         9         466.0     58.0  57.0  14.227451
# ...                 ...      ...   ...        ...
# 1498    10        247.0     41.0  42.0  20.097031
# 1499    9          70.0      9.0  11.0   1.802490
#         10        449.0     68.0  48.0  17.371592
#         11        612.0     74.0  59.0  17.542295
#         12        492.0     69.0  66.0  12.749590
#
# [3214 rows x 4 columns]

# %% [markdown]
# Округлим суммарные за месяц ГБ в большую сторону:

# %%
result['gb_used'] = np.ceil(result['gb_used'])

# %% [markdown]
# Заполним пропуски 0:

# %%
result = result.fillna(0)

# %%
result.rename(columns={
    'duration': 'min_used',
    'user_id': 'calls_done',
    'id': 'mess_used',
}, inplace=True
             )

# %% [markdown]
# Посчитаем количество уникальных пользователей в `result`:

# %%
display(result.index.to_frame().iloc[:, 0].nunique())
# Out:
# 498

# %% [markdown]
# В `data_users` насчитывается 500 абонентов "Мегалайн". Разница показывает: 2 пользователя не воспользовались услугами связи. Дополним `result` строками о пассивных пользователях.

# %%
active = result.index.to_frame().iloc[:, 0].unique()
all_users = data_users.index
passive = list(set(all_users) - set(active))
passive
# Out:
# [1128, 1371]

# %% [markdown]
# Избавимся от `MultiIndex` и соединим `result`, `data_users` и `data_tarif` вместе, заполнив пропуски соответствующими значениями.

# %%
result.reset_index(inplace=True)
result = result.merge(data_users, how='outer', on='user_id')
result
# Out:
#       user_id  month  min_used  calls_done  mess_used  gb_used  age  \
# 0        1000    5.0     159.0        22.0       22.0      3.0   52
# 1        1000    6.0     172.0        43.0       60.0     23.0   52
# 2        1000    7.0     340.0        47.0       75.0     14.0   52
# 3        1000    8.0     408.0        52.0       81.0     14.0   52
# 4        1000    9.0     466.0        58.0       57.0     15.0   52
# ...       ...    ...       ...         ...        ...      ...  ...
# 3211     1499   10.0     449.0        68.0       48.0     18.0   35
# 3212     1499   11.0     612.0        74.0       59.0     18.0   35
# 3213     1499   12.0     492.0        69.0       66.0     13.0   35
# 3214     1128    NaN       NaN         NaN        NaN      NaN   51
# 3215     1371    NaN       NaN         NaN        NaN      NaN   50
#
#      churn_date       city first_name  last_name   reg_date tariff
# 0           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# ...         ...        ...        ...        ...        ...    ...
# 3211        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3212        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3213        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3214 2018-12-23   Волжский     Ксения     Агаева 2018-12-15  ultra
# 3215 2018-12-30       Омск     Ириней   Трофимов 2018-12-25  smart
#
# [3216 rows x 13 columns]

# %%
result.loc[result['month'].isna(), 'month'] = result.loc[result['month'].isna()] \
    .apply(lambda x: (x['reg_date'].month if x['reg_date'].month == x['churn_date'].month else x), axis=1)
result['month'] = result['month'].astype(int)

# %%
result.iloc[:, :6] = result.iloc[:, :6].fillna(0)
result
# Out:
#       user_id  month  min_used  calls_done  mess_used  gb_used  age  \
# 0        1000      5     159.0        22.0       22.0      3.0   52
# 1        1000      6     172.0        43.0       60.0     23.0   52
# 2        1000      7     340.0        47.0       75.0     14.0   52
# 3        1000      8     408.0        52.0       81.0     14.0   52
# 4        1000      9     466.0        58.0       57.0     15.0   52
# ...       ...    ...       ...         ...        ...      ...  ...
# 3211     1499     10     449.0        68.0       48.0     18.0   35
# 3212     1499     11     612.0        74.0       59.0     18.0   35
# 3213     1499     12     492.0        69.0       66.0     13.0   35
# 3214     1128     12       0.0         0.0        0.0      0.0   51
# 3215     1371     12       0.0         0.0        0.0      0.0   50
#
#      churn_date       city first_name  last_name   reg_date tariff
# 0           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# ...         ...        ...        ...        ...        ...    ...
# 3211        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3212        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3213        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3214 2018-12-23   Волжский     Ксения     Агаева 2018-12-15  ultra
# 3215 2018-12-30       Омск     Ириней   Трофимов 2018-12-25  smart
#
# [3216 rows x 13 columns]

# %%
result = pd.merge(result, data_tarif, how='left', left_on='tariff', right_on='tariff_name')

# %% [markdown]
# #### Расчёт выручки
#
#
# Создадим списки с `user_id` для каждого тарифа:

# %%
ultra_users = data_users.loc[data_users['tariff'] == 'ultra'].index
smart_users = data_users.loc[data_users['tariff'] == 'smart'].index

# %% [markdown]
#    Выручки за месяц формируется из:
# - абонентское платы
# - дополнительной выручки за превышение лимитов
#
# Учтём это в функции расчёта суммарной выручки за месяц:

# %%
result.head()
# Out:
#    user_id  month  min_used  calls_done  mess_used  gb_used  age churn_date  \
# 0     1000      5     159.0        22.0       22.0      3.0   52        NaT
# 1     1000      6     172.0        43.0       60.0     23.0   52        NaT
# 2     1000      7     340.0        47.0       75.0     14.0   52        NaT
# 3     1000      8     408.0        52.0       81.0     14.0   52        NaT
# 4     1000      9     466.0        58.0       57.0     15.0   52        NaT
#
#         city first_name  last_name   reg_date tariff  messages_included  \
# 0  Краснодар     Рафаил  Верещагин 2018-05-25  ultra               1000
# 1  Краснодар     Рафаил  Верещагин 2018-05-25  ultra               1000
# 2  Краснодар     Рафаил  Верещагин 2018-05-25  ultra               1000
# 3  Краснодар     Рафаил  Верещагин 2018-05-25  ultra               1000
# 4  Краснодар     Рафаил  Верещагин 2018-05-25  ultra               1000
#
#    gb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# 0                   30.0              3000             1950         150
# 1                   30.0              3000             1950         150
# 2                   30.0              3000             1950         150
# 3                   30.0              3000             1950         150
# 4                   30.0              3000             1950         150
#
#    rub_per_message  rub_per_minute
# 0                1               1
# 1                1               1
# 2                1               1
# 3                1               1
# 4                1               1

# %%
row = result.loc[0]

min_over, mess_over, gb_over = 0, 0, 0
tuples = (
    ('min_used', 'minutes_included', 'rub_per_minute', min_over),
    ('mess_used', 'messages_included', 'rub_per_message', mess_over),
    ('gb_used', 'gb_per_month_included', 'rub_per_gb', gb_over),
)
min_over, mess_over, gb_over = 0, 0, 0
revenue = row['rub_monthly_fee']
for tupl in tuples:
    if row[tupl[0]] > row[tupl[1]]:
        revenue += min_over * row[tupl[2]]
revenue
# Out:
# 1950

# %%
nu = result.loc[0]
type(nu)

def get_revenue(row):
    min_over, mess_over, gb_over = 0, 0, 0
    names = [
        ['min_used', 'minutes_included', 'rub_per_minute', min_over],
        ['mess_used', 'messages_included', 'rub_per_message', mess_over],
        ['gb_used', 'gb_per_month_included', 'rub_per_gb', gb_over],
    ]
    revenue = row['rub_monthly_fee']
    for name in names:
        if row[name[0]] > row[name[1]]:
            name[3] = row[name[0]] - row[name[1]]
            revenue += name[3] * row[name[2]]
    return revenue

result['revenue'] = result.apply(get_revenue, axis=1)
result
# Out:
#       user_id  month  min_used  calls_done  mess_used  gb_used  age  \
# 0        1000      5     159.0        22.0       22.0      3.0   52
# 1        1000      6     172.0        43.0       60.0     23.0   52
# 2        1000      7     340.0        47.0       75.0     14.0   52
# 3        1000      8     408.0        52.0       81.0     14.0   52
# 4        1000      9     466.0        58.0       57.0     15.0   52
# ...       ...    ...       ...         ...        ...      ...  ...
# 3211     1499     10     449.0        68.0       48.0     18.0   35
# 3212     1499     11     612.0        74.0       59.0     18.0   35
# 3213     1499     12     492.0        69.0       66.0     13.0   35
# 3214     1128     12       0.0         0.0        0.0      0.0   51
# 3215     1371     12       0.0         0.0        0.0      0.0   50
#
#      churn_date       city first_name  last_name   reg_date tariff  \
# 0           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4           NaT  Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# ...         ...        ...        ...        ...        ...    ...
# 3211        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3212        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3213        NaT      Пермь     Гектор   Корнилов 2018-09-27  smart
# 3214 2018-12-23   Волжский     Ксения     Агаева 2018-12-15  ultra
# 3215 2018-12-30       Омск     Ириней   Трофимов 2018-12-25  smart
#
#       messages_included  gb_per_month_included  minutes_included  \
# 0                  1000                   30.0              3000
# 1                  1000                   30.0              3000
# 2                  1000                   30.0              3000
# 3                  1000                   30.0              3000
# 4                  1000                   30.0              3000
# ...                 ...                    ...               ...
# 3211                 50                   15.0               500
# 3212                 50                   15.0               500
# 3213                 50                   15.0               500
# 3214               1000                   30.0              3000
# 3215                 50                   15.0               500
#
#       rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  revenue
# 0                1950         150                1               1   1950.0
# 1                1950         150                1               1   1950.0
# 2                1950         150                1               1   1950.0
# 3                1950         150                1               1   1950.0
# 4                1950         150                1               1   1950.0
# ...               ...         ...              ...             ...      ...
# 3211              550         200                3               3   1150.0
# 3212              550         200                3               3   1513.0
# 3213              550         200                3               3    598.0
# 3214             1950         150                1               1   1950.0
# 3215              550         200                3               3    550.0
#
# [3216 rows x 21 columns]

# %%
result.groupby('tariff')['revenue'].mean()
# Out:
# tariff
# smart    1289.641704
# ultra    2070.030426
# Name: revenue, dtype: float64

# %% [markdown]
# Теперь мы нашли выручку по всем клиентам и по всем статьям, а также имеем все данные сведённые в один датафрейм.

# %% [markdown]
# ## Анализ данных
#
# В этом разделе опишем поведение клиентов оператора, исходя из тарифа. Для этого взглянем на количества минут разговора, сообщений и ГБ и посчитаем среднее количество, дисперсию и стандартное отклонение, а также построим гистограммы.
#
# Статистические метрики сведём в одну таблицу для каждого тарифа.

# %%
ultra_data = result.loc[result['tariff'] == 'ultra']
smart_data = result.loc[result['tariff'] == 'smart']

# %%
describe_spent = ['min_used', 'mess_used', 'gb_used']

# %%
ultra_res = ultra_data[describe_spent]
st_ultra = ultra_res.describe().iloc[[1, 5]]
std_ultra = ultra_res.apply(lambda x: np.std(x, ddof=1)).to_frame().transpose()  # НЕ СМЕЩЁННАЯ STD
var_ultra = ultra_res.apply(lambda x: np.var(x, ddof=1)).to_frame().transpose()  # НЕ СМЕЩЁННАЯ ДИСПЕРСИЯ
st_ultra = pd.concat([st_ultra, std_ultra, var_ultra])
st_ultra.index = ['mean', 'median', 'std', 'var']

smart_res = smart_data[describe_spent]
st_smart = smart_res.describe().iloc[[1, 5]]
std_smart = smart_res.apply(lambda x: np.std(x, ddof=1)).to_frame().transpose()  # НЕ СМЕЩЁННАЯ STD
var_smart = smart_res.apply(lambda x: np.var(x, ddof=1)).to_frame().transpose()  # НЕ СМЕЩЁННАЯ ДИСПЕРСИЯ
st_smart = pd.concat([st_smart, std_smart, var_smart])
st_smart.index = ['mean', 'median', 'std', 'var']

display(st_ultra)
display(st_smart)
# Out:
#              min_used    mess_used    gb_used
# mean       526.089249    49.313387  19.474645
# median     518.000000    38.000000  19.000000
# std        317.887549    47.806040   9.868057
# var     101052.493549  2285.417425  97.378544
#             min_used   mess_used    gb_used
# mean      417.747534   33.369058  16.321525
# median    421.500000   28.000000  17.000000
# std       190.476754   28.230396   5.756167
# var     36281.393836  796.955256  33.133453

# %% [markdown]
# Частотная гистограмма плохо подходит непрерывным переменным: частота попадания значений в интервалы зависит от выбора границ интервалов. Исходя из этого будем подбирать интервалы по размеры стандартного отклонения. Для расчёта граница напишем соответствующую функцию.

# %%
# function for bins:
def get_bins(st_data):
    mean = st_data.loc['mean']
    std = st_data.loc['std']
    left_mean = [0] + [(mean - x * std) for x in range(1, 4) if (mean - x * std) > 0]
    right_mean = [mean] + [(mean + x * std) for x in range(1, 5)]
    return sorted(left_mean + right_mean)

display(ultra_res['min_used'].hist(bins=get_bins(st_ultra['min_used']), alpha=0.5));
display(smart_res['min_used'].hist(bins=get_bins(st_smart['min_used']), alpha=0.5));

# %% [markdown]
# *Оранжевая гистограмма  - использование минут на тарифе "Смарт";
# Синяя гистограмма - использование минут на тарифе тарифа "Ультра".*

# %%
display(ultra_res['mess_used'].hist(bins=get_bins(st_ultra['mess_used']), alpha=0.5))
display(smart_res['mess_used'].hist(bins=get_bins(st_smart['mess_used']), alpha=0.5))

# %% [markdown]
# *Оранжевая гистограмма - использование сообщений на тарифе "Смарт";
# Синяя гистограмма - использование сообщений на тарифе "Ультра".*

# %%
display(ultra_res['gb_used'].hist(bins=get_bins(st_ultra['gb_used']), alpha=0.5));
display(smart_res['gb_used'].hist(bins=get_bins(st_smart['gb_used']), alpha=0.5));

# %% [markdown]
# *Оранжевая гистограмма - использование ГБ на тарифе "Смарт";
# Синяя гистограмма - использование ГБ на тарифе "Ультра".*

# %% [markdown]
# **ВЫВОДЫ**
#
# 1. Средние, стандартное отклонения и дисперсии по тарифу "Ультра" заметно выше.
# 2. Лимиты по сообщениям и по минутам иногда превышаются по тарифу "Смарт" и практически никогда по тарифу "Ультра"
# 3. Лимиты по ГБ обычно превышаются на тарифе "Смарт"
# 4. Все гистограммы для тарифа "Ультра" имеют *правое* смещение - там медианы меньше средней.
# 5. В целом на обоих тарифах, распределение заметно ближе к нормальному по минутам и мегабайтам.

# %% [markdown]
# ##  Проверка статистических гипотез
# Следуют проверить следующие гипотезы:
# 1. средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются;
# 2. средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов.
# Значение alpha зададим равным 1%.
#
# Поясните:
# - как вы формулировали нулевую и альтернативную гипотезы;
# - какой критерий использовали для проверки гипотез и почему.

# %% [markdown]
# ### Проверка гипотезы №1
#
#
# Мы имеем две независимые совокупности: абонентов двух разных тарифов. Нужно проверить гипотезу по выборкам абонентов: различаются ли средние выручки. Взглянем на выборочную средние по тарифам:

# %%
result.groupby('tariff')['revenue'].mean()
# Out:
# tariff
# smart    1289.641704
# ultra    2070.030426
# Name: revenue, dtype: float64

# %% [markdown]
# Как видно, для данной выборки средние сильно различаются. Нам нужно выяснить как ведут себя средние генеральных совокупностей.
#
# Для этого формулировка нулевой гипотезы звучит так: средние выручки равны.
#
# Соответственно гипотеза H1: средние выручки не равны.
#
# Для формулировки нулевой гипотезы, исходили из того, что верно некое равенство. Альтернативная гипотеза отвергает верность равенства.
#
#
# Отвергнуть или принять нулевую гипотезу поможет t-тест. Рассмотрим, подходит ли он нам по его ограничениям:
# 1. Генеральные совокупности не должны зависеть друг от друга. Совокупность абонентов одного тарифа, не влияет на совокупность абонентов другого тарифа.
# 2. Выборочные средние должны быть нормально распределены.Благодаря ЦПТ, если размер выборки составляет хотя бы несколько десятков значений, выборочные средние, которые можно получить из одной и той же генеральной совокупности, будут распределены нормально вокруг истинного среднего этой совокупности. Напомним, это утверждение верно, даже если сама генеральная совокупность не распределена нормально. У нас размеры выборок: 149 и 351 - это условие подходит.
# 3. Дисперсии рассматриваемых генеральных совокупностей должны быть равны. Так как мы имеем разные по размеры выборки, мы укажем в параметрах функции для расчёта `equal_var` равным `False` - это условия обойдём таким образом.
#
# Для проверки гипотезы будем использовать критерий `p-value` - это вероятность получить наблюдаемый или еще более далекий от предполагаемого результат при условии, что нулевая гипотеза верна.

# %%
ultra_sample = ultra_data.groupby('user_id')['revenue'].mean()
smart_sample = smart_data.groupby('user_id')['revenue'].mean()
alpha = .01

results = st.ttest_ind(ultra_sample, smart_sample, equal_var=False)
print(f'p-value: {results.pvalue}')
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-value: 7.2487241982126e-60
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод:** по значению `pvalue` мы видим почти *нулевую вероятность* того что средние выручки по тарифам будут одинаковые.

# %% [markdown]
# ### Проверка гипотезы №2
#
# В данном случае выборка поделилась на две по признаку `city`: абонент из Москвы или не из Москвы. Требуется определить, могут ли быть средние выручки по этим выборкам близки. Найдём, также, средние выручки по данным выборкам.

# %%
mos_result = result.loc[result['city'] == 'Москва']
prov_result = result.loc[result['city'] != 'Москва']

# %%
display(mos_result['revenue'].mean())
display(prov_result['revenue'].mean())
# Out:
# 1546.7135842880523
# 1524.7251439539348

# %% [markdown]
# Как видим, средние выручки по этим выборкам очень близки. Выясним, какова вероятность, что средние выручки по ген. совокупностям совпадают.

# %% [markdown]
# #### Статистические расчёты по гипотезе №2
#
# Формулировка нулевой гипотезы звучит так: средние выручки равны.
#
# Соответственно гипотеза H1: средние выручки не равны.
#
# Для проверки нулевой гипотезы используем t-тест. Рассмотрим, подходит ли он нам по его ограничениям:
# 1. Генеральные совокупности не должны зависеть друг от друга. Совокупность абонентов из разных регионов не влияют друг на друга.
# 2. Выборочные средние должны быть нормально распределены.Благодаря ЦПТ, если размер выборки составляет хотя бы несколько десятков значений, выборочные средние, которые можно получить из одной и той же генеральной совокупности, будут распределены нормально вокруг истинного среднего этой совокупности. Напомним, это утверждение верно, даже если сама генеральная совокупность не распределена нормально. У нас размеры выборок более 30 - это условие подходит.
# 3. Дисперсии рассматриваемых генеральных совокупностей должны быть равны. Так как мы имеем разные по размеры выборки, мы укажем в параметрах функции для расчёта `equal_var` равным `False` - это условия обойдём таким образом.
#
# Мы имеем две независимые совокупности: абонентов двух разных тарифов.

# %%
mos_sample = mos_result.groupby('user_id')['revenue'].mean()
prov_sample = prov_result.groupby('user_id')['revenue'].mean()
alpha = .01
results = st.ttest_ind(mos_sample, prov_sample, equal_var=False)
print(results.pvalue)
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# 0.3557950151396201
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **Вывод:** Есть большая вероятность, что средняя выручка в Москве и регионах равны.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. Лимит минут по тарифу "Ультра" очень редко превышается. Причём средняя по минутам для пользователей тарифа "Ультра"
# близка к лимиту минут по тарифу "Смарт". Средний пользователь "Ультра" использует не более 20 % лимита по минутам и 6 % по
# сообщениям при этом абон. плата по тарифу на 254% выше чем на тарифе "Смарт".
#
# 2. Активно используются ГБ на обоих тарифах. На тарифе "Смарт" лимит ГБ обычно превышается. Стандартное отклонение в 6 ГБ -
# а это доп. выручка для "Мегалайна" и доп. расход для пользователя, который с большой вероятностью может доходить
# до 1200 рублей.
#
# 3. Формы гистограмм для минут и ГБ близки к форме гистограммы нормального распределения. Гистограммы минут имеют выраженное
# правое смещение - это говорит о том, что большинство пользователей сообщений отсылают мало.
#
# 4. Средние выручки тарифов "Ультра" и "Смарт" очень маловероятно, что будут равны.
#
# 5. Средние выручки абонентов "Мегалайна" из Москвы и в целом из остальных регионов с очень большой вероятностью могут быть равны.
