# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span><ul class="toc-item"><li><span><a href="#Описание-и-загрузка-данных" data-toc-modified-id="Описание-и-загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание и загрузка данных</a></span></li></ul></li><li><span><a href="#Проведите-исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Проведите-исследовательский-анализ-данных-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Проведите исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Изучение-датасета" data-toc-modified-id="Изучение-датасета-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучение датасета</a></span><ul class="toc-item"><li><span><a href="#Пhосмотр-датасета-на-пропуски.-Изучение-средних-значений-и-стандартных--отклонений." data-toc-modified-id="Пhосмотр-датасета-на-пропуски.-Изучение-средних-значений-и-стандартных--отклонений.-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Пhосмотр датасета на пропуски. Изучение средних значений и стандартных  отклонений.</a></span></li><li><span><a href="#Просмотр-средних-значений-признаков-в-группах,-разделённых-по-целевому-признаку." data-toc-modified-id="Просмотр-средних-значений-признаков-в-группах,-разделённых-по-целевому-признаку.-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Просмотр средних значений признаков в группах, разделённых по целевому признаку.</a></span></li><li><span><a href="#Построение-столбчатых-гистограмм-и-распределения-признаков-для-групп,-разделённых-по-целевому-признаку." data-toc-modified-id="Построение-столбчатых-гистограмм-и-распределения-признаков-для-групп,-разделённых-по-целевому-признаку.-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Построение столбчатых гистограмм и распределения признаков для групп, разделённых по целевому признаку.</a></span></li><li><span><a href="#Построение-матрицы-корреляций." data-toc-modified-id="Построение-матрицы-корреляций.-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Построение матрицы корреляций.</a></span></li></ul></li></ul></li><li><span><a href="#Построение-модели-прогнозирования-оттока-пользователей" data-toc-modified-id="Построение-модели-прогнозирования-оттока-пользователей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели прогнозирования оттока пользователей</a></span><ul class="toc-item"><li><span><a href="#Разбиение-выборки" data-toc-modified-id="Разбиение-выборки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Разбиение выборки</a></span></li><li><span><a href="#Обучение-модели-на-train-выборке" data-toc-modified-id="Обучение-модели-на-train-выборке-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение модели на train-выборке</a></span><ul class="toc-item"><li><span><a href="#Обучение-модели-логистической-регрессией" data-toc-modified-id="Обучение-модели-логистической-регрессией-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Обучение модели логистической регрессией</a></span></li><li><span><a href="#Обучение-модели-случайным-лесом" data-toc-modified-id="Обучение-модели-случайным-лесом-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Обучение модели случайным лесом</a></span></li></ul></li></ul></li><li><span><a href="#Кластеризация-пользователей" data-toc-modified-id="Кластеризация-пользователей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Кластеризация пользователей</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Стандартизация-данных" data-toc-modified-id="Стандартизация-данных-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Стандартизация данных</a></span></li><li><span><a href="#Построение-матрицы-расстояний.-Дендрограмма.-Предположение-о-количестве-кластеров." data-toc-modified-id="Построение-матрицы-расстояний.-Дендрограмма.-Предположение-о-количестве-кластеров.-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Построение матрицы расстояний. Дендрограмма. Предположение о количестве кластеров.</a></span></li><li><span><a href="#Обучение-модель-кластеризации-на-основании-алгоритма-K-Means-и-прогнозирование-кластеров-клиентов." data-toc-modified-id="Обучение-модель-кластеризации-на-основании-алгоритма-K-Means-и-прогнозирование-кластеров-клиентов.-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>Обучение модель кластеризации на основании алгоритма K-Means и прогнозирование кластеров клиентов.</a></span></li><li><span><a href="#Анализ-средних-значений-признаков-для-кластеров" data-toc-modified-id="Анализ-средних-значений-признаков-для-кластеров-4.0.4"><span class="toc-item-num">4.0.4&nbsp;&nbsp;</span>Анализ средних значений признаков для кластеров</a></span></li><li><span><a href="#Распределения-признаков-для-кластеров." data-toc-modified-id="Распределения-признаков-для-кластеров.-4.0.5"><span class="toc-item-num">4.0.5&nbsp;&nbsp;</span>Распределения признаков для кластеров.</a></span></li><li><span><a href="#Доля-оттока-по-кластерам" data-toc-modified-id="Доля-оттока-по-кластерам-4.0.6"><span class="toc-item-num">4.0.6&nbsp;&nbsp;</span>Доля оттока по кластерам</a></span></li></ul></li></ul></li><li><span><a href="#Сформулируйте-выводы-и-сделайте-базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Сформулируйте-выводы-и-сделайте-базовые-рекомендации-по-работе-с-клиентами-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами</a></span></li><li><span><a href="#Как-будут-проверять-мой-проект?" data-toc-modified-id="Как-будут-проверять-мой-проект?-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Как будут проверять мой проект?</a></span></li></ul></div>

# %% [markdown]
# <font size = 5>**Проект "Прогнозирование оттока клиентов для сети фитнес-центров на основе машинного обучения"**<font size>

# %% [markdown]
# # Введение
#
#   В данном проекте, решается бизнес-задача по снижению оттока клиентов из сети фитнес-центров. Рекомендации как это сделать представлены в **разделе 5**.
#
#   Рекомендация строится на основе выделения целевых групп клиентов (**раздел 4**) и прогноза по оттоку клиентов на уровни следующего месяца (**раздел 3**).
#
#   В **разделе 2** проведён разведочный анализ данных, а их загрузка в **разделе 1**.
#
#
#
# Основные вопросы, на которые важно ответить:
# - Что мы прогнозируем и какую бизнес-задачу этим решаем?
#     - Прогнозируем вероятность оттока на уровне следующего месяца
#     - Снижение оттока клиентов
# - Какие данные для этого есть?
#     - Для решения задачи предоставлена база клиентских анкет
# - Кто и как будет использовать вашу модель (как она встраивается в бизнес-процесс)?
#     - Руководство сети фитнес-центров на основе прогноза оттока клиентов и веса выявленных причин их оттока будет формировать стратегию их удержания.
# - Какие результаты вы хотите получить?
#     - как в компании до вас решали эту проблему и насколько успешно?
#         - Скорее всего такая задача не решалась при помощи ML-инструментов
#     - какой бизнес-эффект может дать ваша модель?
#         - Увеличение выручки за счёт снижения оттока клиентов
#     - достаточно ли у вас ресурсов (время, люди, финансы, вычислительные ресурсы)?
#         - достаточно
#     - по каким метрикам вы будете оценивать качество работы вашей модели?
#         - снижение вероятности оттока
#     - есть ли успешные бенчмарки (примеры с рынка) использования машинного обучения в подобных задачах?
#         - думаю есть, но я их пока не видел

# %% [markdown]
# ## Описание и загрузка данных
#
# Набор данных включает следующие поля:
# - `Churn` — факт оттока в текущем месяце;
#
# Текущие поля в датасете:
#
# Данные пользователя за предыдущий до проверки факта оттока месяц:
# - `gender` — пол
# - `Near_Location` — проживание или работа в районе, где находится фитнес-центр
# - `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента)
# - `Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента)
# - `Phone` — наличие контактного телефона
# - `Age` — возраст
# - `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах)
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
# - `Contract_period` — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год)
# - `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах)
# - `Group_visits` — факт посещения групповых занятий
# - `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента
# - `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц
# - `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats as st
import numpy as np
import math as mth

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.cluster import KMeans

from scipy.cluster.hierarchy import dendrogram, linkage

# %%
pd.set_option('display.max_columns', 50)
pd.options.mode.chained_assignment = None  # default='warn'
# plt.rcParams['figure.figsize'] = [10, 10]

# %%
pth_data = 'gym_churn.csv'
pth_folder = '/datasets/'

try:
    df = pd.read_csv(pth_data, engine='python')
except:
    df = pd.read_csv(pth_folder + pth_data, engine='python')

# %% [markdown]
# # Проведите исследовательский анализ данных (EDA)
#
# - Посмотрите на датасет: есть ли в нём отсутствующие значения (пропуски), изучите средние значения и стандартные отклонения (пригодится метод describe());
# - Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());
# - Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# - Постройте матрицу корреляций и отобразите её.

# %%
df.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
df.columns = [col.lower() for col in df.columns]

# %% [markdown]
# ## Изучение датасета
#
# ### Пhосмотр датасета на пропуски. Изучение средних значений и стандартных  отклонений.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   float64
#  10  lifetime                           4000 non-null   int64
# ...

# %%
len(df[df.duplicated()])
# Out:
# 0

# %%
df.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# Пропусков нет. Дубликатов нет. Большинство полей содержит бинарные данные. Бинарный вид имеет целевая переменная.
#
# Изучение значений:
# - `gender`: среднее значение и стандартное отклонение близки, значит количество мужчин и женщин посещающих фитнес-центры примерно равно
# - `near_location`: среднее значение ближе к единице при стандартном отклонении 0,36, значит фитнес-центры посещают больше людей в зависимости от локации
# - `partner`: `mean` и `std` очень близки, значит половина посетителей пришло по партнёрской программе
# - `promo_friends`: `mean` заметно меньше `std`, т. е. самостостоятельно стали клиентами большинство посетителей
# - `phone`: большинство телефон предоставило
# - `contract_period`: надо смотреть гистограмму
# - `group_visits`: `mean` и `std` очень близки
# - `age`: посетителя в общем случае 29 лет +/- 3 года
# - `avg_additional_charges_total`:
# - `month_to_end_contract`: признак похож на `contract_period`
# - `lifetime`: `mean` и `std` очень близки
# - `avg_class_frequency_total`: средний клиент обычно посещает бассейн два раза в неделю
# - `avg_class_frequency_current_month`: средний клиент обычно посещает бассейн два раза в неделю - признак похож на предыдущий

# %% [markdown]
# ### Просмотр средних значений признаков в группах, разделённых по целевому признаку.

# %%
for value, group_data in df.groupby('churn'):
    if value == 0:
        print('Оставшиеся клиенты') 
        non_churn = group_data
    else:
        print('Потерянные клиенты')
        churn_client = group_data
    print(group_data.mean())    
    print('')
# Out:
# Оставшиеся клиенты
# gender                                 0.510037
# near_location                          0.873086
# partner                                0.534195
# promo_friends                          0.353522
# phone                                  0.903709
# contract_period                        5.747193
# group_visits                           0.464103
# age                                   29.976523
# avg_additional_charges_total         158.445715
# month_to_end_contract                  5.283089
# lifetime                               4.711807
# avg_class_frequency_total              2.024876
# avg_class_frequency_current_month      2.027882
# churn                                  0.000000
# dtype: float64
#
# Потерянные клиенты
# gender                                 0.510839
# near_location                          0.768143
# partner                                0.355325
# promo_friends                          0.183789
# ...

# %% [markdown]
# ### Построение столбчатых гистограмм и распределения признаков для групп, разделённых по целевому признаку.

# %%
category = ['contract_period', 'age', 'avg_additional_charges_total', 'month_to_end_contract', 'lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month']

for col in df.drop(columns=['churn']).columns:
    plt.figure(figsize=(5, 5))
    sns.histplot(data=df, x=col, hue='churn', color='red', multiple='dodge')
    plt.show()

# %% [markdown]
# Так как, целевой признак `churn` имеет всего два значения диаграммы рассеяния получается малоинформотивными. Оставим только гистограммы.

# %% [markdown]
# ### Построение матрицы корреляций.

# %%
cm = df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, square=True)
plt.title('Матрица корреляций')
plt.show()

# %% [markdown]
# Сделаем признак `contract_period` категориальным

# %%
df = pd.get_dummies(df, columns=['contract_period'])
cm = df.corr()
plt.figure(figsize=(12, 12))

sns.heatmap(cm, annot=True, square=True)
plt.title('Матрица корреляций')
plt.show()

# %% [markdown]
# Выводы по EDA:
# - данные качественные (не имеют пропусков и дубликатов)
# - большинство полей содержат бинарные данные, в том числе и целевой признак 'churn'
# - Ярко выраженной корреляции с целевым признаком нет.  Есть средние обратные корреляции с `lifetime`, `avg_class_frequence_current_month`, `age`, `contract_period`, `month_to_end_period`. Средняя прямая корреляция с наличием одномесячных абонементов.
# - Поля `contract_period` и `month_to_end_period` хорошо коррелируют. Так как поле `contract_period` содержит всё-таки немного другие данные, возможно стоит сделать его категориальным.
# - Заметные отличия наблюдаются в признаках:
#     - `partner` - чаще остаются клиенты по партнёрской программе
#     - `near_location` - люди остаются клиентами чаще если бассейн близко
#     - `contract_period` - если абонемент на 6 и более месяцев люди остаются
#     - `group_visits` - факт посещения групповых занятий играет на удержание клиентов
#     - `month_to_end_contract` - если осталось до конца абонемента 1-2 месяца, шансы на утерю клиента повышаются
#     - `lifetime` - клиентов с одномесочным лайфтаймом чаще теряются
#     - `avg_class_frequency_current_month` - если количество посещений снижается до одного, такой клиент чаще становится утерянным.
# - Каких либо серьёзных выбросов в данных не выявлено

# %% [markdown]
# # Построение модели прогнозирования оттока пользователей
#
# Постройте модель бинарной классификации пользователей, где целевой признак — факт оттока пользователя в следующем месяце:
# - Разбейте данные на обучающую и валидационную выборку функцией train_test_split().
# - Обучите модель на train-выборке двумя способами:
#        - логистической регрессией
#        - случайным лесом
# - Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
#
# Не забудьте указать параметр random_state при разделении выборки и задании алгоритма.
#
# ## Разбиение выборки

# %%
X = df.drop(columns=['churn'])
y = df.churn

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=0)

# %% [markdown]
# ## Обучение модели на train-выборке
# ### Обучение модели логистической регрессией

# %%
model_lr = LogisticRegression(solver='liblinear')
model_lr.fit(X_train, y_train)

predictions_lr = model_lr.predict(X_test)
# probabilities = model.predict_proba(X_test_st)[:,1]

print('Accuracy LogisticRegression: {:.2f}'.format(accuracy_score(y_test, predictions_lr)))
print('Precision LogisticRegression: {:.2f}'.format(precision_score(y_test, predictions_lr)))
print('Recall LogisticRegression: {:.2f}'.format(recall_score(y_test, predictions_lr)))
# Out:
# Accuracy LogisticRegression: 0.92
# Precision LogisticRegression: 0.86
# Recall LogisticRegression: 0.82

# %% [markdown]
# ### Обучение модели случайным лесом

# %%
model_rf = RandomForestClassifier(n_estimators=20, random_state=0)
model_rf.fit(X_train, y_train)

predictions_rf = model_rf.predict(X_test)

print('Accuracy RandomForestRegressor: {:.2f}'.format(accuracy_score(y_test, predictions_rf)))
print('Precision RandomForestRegressor: {:.2f}'.format(precision_score(y_test, predictions_rf)))
print('Recall RandomForestRegressor: {:.2f}'.format(recall_score(y_test, predictions_rf)))
# Out:
# Accuracy RandomForestRegressor: 0.92
# Precision RandomForestRegressor: 0.85
# Recall RandomForestRegressor: 0.80

# %% [markdown]
# Доля правильный ответов для оттока и оставшихся клиентов у обеих моделей одинакова, но метрики precision и recall всё таки лучше у модели логистической регрессии, т.е. такая модель лучше прогнозирует доля правильных ответов для оттока и сколько реальных фактов оттока выявлено в валидационной выборке.

# %% [markdown]
# # Кластеризация пользователей
#
# ### Стандартизация данных

# %%
scaler = StandardScaler()
df_sc = scaler.fit_transform(df)

# %% [markdown]
# ### Построение матрицы расстояний. Дендрограмма. Предположение о количестве кластеров.

# %%
linked = linkage(df_sc, method = 'ward')

plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Дендрограмма')
plt.show()

# %% [markdown]
# Видим 3 разных цвета, значит алгоритм предполагает оптимальное число кластеров равно 3.

# %% [markdown]
# ### Обучение модель кластеризации на основании алгоритма K-Means и прогнозирование кластеров клиентов.
#
# Договоримся за число кластеров принять n=5.

# %%
km = KMeans(n_clusters=5, random_state=0)
labels = km.fit_predict(df_sc)

# %% [markdown]
# ### Анализ средних значений признаков для кластеров

# %%
df['cluster_km'] = list(labels)
df.groupby('cluster_km').mean().style.background_gradient()
# Out:
# <style type="text/css">
# #T_2212d_row0_col0, #T_2212d_row0_col14, #T_2212d_row2_col1, #T_2212d_row2_col12, #T_2212d_row3_col2, #T_2212d_row3_col3, #T_2212d_row3_col5, #T_2212d_row3_col7, #T_2212d_row3_col8, #T_2212d_row3_col15, #T_2212d_row4_col1, #T_2212d_row4_col4, #T_2212d_row4_col6, #T_2212d_row4_col9, #T_2212d_row4_col10, #T_2212d_row4_col11, #T_2212d_row4_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2212d_row0_col1, #T_2212d_row3_col10 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_2212d_row0_col2 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_2212d_row0_col3 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Наблюдения:
# 1. Клиенты группы 1 полностью не из районов фитнес-центров. Диаметрально противоположная ситуация у группы 2.
# 2. Больше всего клиентов по партнёрским программам в 3 группе.
# 3. Клиентов группы 1 почти все пришли в фитнес-центр самостоятельно.
# 4. Клинты группы 1 меньше всего настроены к групповым занятиям.
# 5. Всем клиентам в 4 группе остался ровно месяц до окончания контракта. Для средних клиентов из групп 0 и 3 характерно 5 и почти 11 месяцев до конца контракта.
# 6. Самый малый средний лайфтайм наблюдается в группе 2.
# 7. Для клиентов из групп 0 характерна покупка полугодового абонемента.
# 8. Для клиентов из групп 4 характерна покупка месячного абонемента.
# 9. Для клиентов из групп 3 характерна покупка годового абонемента.

# %% [markdown]
# ### Распределения признаков для кластеров.

# %%
for col in df.columns:
    plt.figure(figsize=(5, 5))
    sns.displot(data=df, x=col, hue='cluster_km', palette='tab10', multiple="stack")
    plt.show()

# %% [markdown]
# Подтвердились наблюдения по средним значениям в кластере по:
# - `near_location`
# - месячным, полугодовым и годовым абонементам
#
# Самые преданные клиенты из 0, 3 и 4 групп. Им характерно:
# - клиенты 3 группы покупают годовой абонемент
# - клиенты 0 группы покупают полугодовой абонемент
# - клиенты из 0 и 3 групп, как правило, более чем за месяц покупают следующий абонемент
# - клиенты из 4 группы живут либо работают рядом с фитнес-центром и покупают одномесячные абонементы
# - преданные клиенты в среднем ходят в фитнес-центр 2 раза в неделю
#
# Клиенты попадают в отток чаще всего из группы 2. Для таких клиентов характерно:
# - одномесячный абонемент
# - близкая локация
# - посещение 1-1,5 раза в неделю
# - от клиентов из 4 группы их отличает короткий лайфтайм и малые дополнительные расходы.
#
# Также, есть группа 2 со 100% не близкой локацией - в этой группе клиенты попадают в отток, скорее всего, из-за локации. Им также характерен одномесячный абонемент.

# %% [markdown]
# ### Доля оттока по кластерам

# %%
df.groupby('cluster_km')['churn'].sum() / df.groupby('cluster_km')['churn'].count()
# Out:
# cluster_km
# 0    0.102217
# 1    0.534216
# 2    0.954362
# 3    0.021921
# 4    0.003876
# Name: churn, dtype: float64

# %% [markdown]
# Самые преданные клиенты из 4 группы. Обратная ситуация наблюдается в группе 2.

# %% [markdown]
# # Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами
#
# Основные выводы:
# 1. В отток попадают клиенты с краткосрочными абонементами и со средним посещением 1-1,5 раза в неделю. Эти клиенты могут рядом жить или работь, а может быть и наоборот.
# 2. Если человек ходит в фитнес-центр более 4 месяцев, вероятность его попадания в отток сильно снижается.
# 3. Преданные клиенты покупают среднесрочные и долгосрочные абонементы.
#
# Рекомендации:
# 1. Нужно выявлять новых клиентов посещающих фитнес-центр около двух раз в неделю - такие клиенты с бОльшей вероятностью станут постоянными клиентами.
# 2. Клиентов из п. 1 следует опекать по крайней мере до 4 месяцев. Опека должна стимулировать:
#     - продолжение посещений фитнес-центра минимум 2 раза в неделю. Этого можно попробовать достичь бонусными баллами за второе посещение за неделю. Баллы трансформируются в скидку на среднесрочный или долгосрочный абонемент.
# 3. Есть группа клиентов c "не близкой" `near_location` и с краткосрочными абонементами - эти клиенты в большинстве своём идут в отток, так как для многих этот фактор решающий. Нужны сильные конкурентные преимущества чтобы сохранить этих клиентов.
# 4. Следует стимулировать покупку среднесрочных и краткосрочных абонементов, причём минимум за 1 месяц до окончания текущего абонемента для не краткосрочных абонементов. Клиентов с месячными абонементами следует оповещать об окончании их абонемента за 10 дней и предлагать ощутимые скидки на не краткосрочные абонементы.
